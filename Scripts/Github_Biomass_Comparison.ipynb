# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re   
import sys 

plt.figure(figsize=(15,8))
plt.xlabel('Approaches',fontsize=14)
plt.ylabel('Biomass Value (mmol gDW-1h-1)',fontsize=14)
plt.title('Comparison of Biomass levels between approaches',fontsize=14)

#Wild-type


wt_biomass = pd.read_csv("WT_biomass.txt",sep="\s+")
biomass = wt_biomass.rename(columns={'Biomass': 'Wild-type'})
wt_col = biomass.columns[1]
wt_numb = pd.to_numeric(wt_col)
plt.scatter(biomass.columns[0], wt_numb, s=150, marker='o', color='dimgray', alpha=1, label='Wild-type Biomass')


#ADH1

ADH1_biomass = pd.read_csv("ADH1_biomass.txt",sep="\s+")
ADH1_col = ADH1_biomass.columns[1]
ADH1_numb = pd.to_numeric(ADH1_col)
plt.scatter(ADH1_biomass.columns[0], ADH1_numb, s=150, marker='o', color='mediumseagreen', alpha=1, label='ADH1 Biomass')

#GPD1

GPD1_biomass = pd.read_csv("GPD1_biomass.txt",sep="\s+")
GPD1_col = GPD1_biomass.columns[1]
GPD1_numb = pd.to_numeric(GPD1_col)
plt.scatter(GPD1_biomass.columns[0], GPD1_numb, s=150, marker='o', color='mediumseagreen', alpha=1, label='GPD1 Biomass')

#HC23

HC23_biomass = pd.read_csv("HC23_biomass.txt",sep="\s+")
HC23_col = HC23_biomass.columns[1]
HC23_numb = pd.to_numeric(HC23_col)
plt.scatter(HC23_biomass.columns[0], HC23_numb, s=150, marker='o', color='mediumseagreen', alpha=1, label='HC23 Biomass')

#HC16

HC16_biomass = pd.read_csv("HC16_biomass.txt",sep="\s+")
HC16_col = HC16_biomass.columns[1]
HC16_numb = pd.to_numeric(HC16_col)
plt.scatter(HC16_biomass.columns[0], HC16_numb, s=150, marker='o', color='tomato', alpha=1, label='HC16 Biomass')



#HC30

HC30_biomass = pd.read_csv("HC30_biomass.txt",sep="\s+")
HC30_col = HC30_biomass.columns[1]
HC30_numb = pd.to_numeric(HC30_col)
plt.scatter(HC30_biomass.columns[0], HC30_numb, s=150, marker='o', color='tomato', alpha=1, label='HC30 Biomass')

#HC32

HC32_biomass = pd.read_csv("HC32_biomass.txt",sep="\s+")
HC32_col = HC32_biomass.columns[1]
HC32_numb = pd.to_numeric(HC32_col)
plt.scatter(HC32_biomass.columns[0], HC32_numb, s=150, marker='o', color='tomato', alpha=1, label='HC32 Biomass')

#HC42

HC42_biomass = pd.read_csv("HC42_biomass.txt",sep="\s+")
HC42_col = HC42_biomass.columns[1]
HC42_numb = pd.to_numeric(HC42_col)
plt.scatter(HC42_biomass.columns[0], HC42_numb, s=150, marker='o', color='tomato', alpha=1, label='HC42 Biomass')


#FM62

FM62_biomass = pd.read_csv("FM62_biomass.txt",sep="\s+")
FM62_col = FM62_biomass.columns[1]
FM62_numb = pd.to_numeric(FM62_col)
plt.scatter(FM62_biomass.columns[0], FM62_numb, s=150, marker='o', color='tomato', alpha=1, label='FM62 Biomass')


#TPI1

TPI1_biomass = pd.read_csv("TPI1_biomass.txt",sep="\s+")
TPI1_col = TPI1_biomass.columns[1]
TPI1_numb = pd.to_numeric(TPI1_col)
plt.scatter(TPI1_biomass.columns[0], TPI1_numb, s=150, marker='o', color='dimgray', alpha=1, label='TPI1 Biomass')


#PDC

PDC_biomass = pd.read_csv("PDC_biomass.txt",sep="\s+")
PDC_col = PDC_biomass.columns[1]
PDC_numb = pd.to_numeric(PDC_col)
plt.scatter(PDC_biomass.columns[0], PDC_numb, s=150, marker='o', color='dimgray', alpha=1, label='PDC Biomass')





#TAM3KO

TAM3KO_biomass = pd.read_csv("TAM3KO_biomass.txt",sep="\s+")
TAM3KO_col = TAM3KO_biomass.columns[1]
TAM3KO_numb = pd.to_numeric(TAM3KO_col)
plt.scatter(TAM3KO_biomass.columns[0], TAM3KO_numb, s=150, marker='o', color='dimgray', alpha=1, label='TAM3KO Biomass')


plt.grid(True)
